# %%
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
airbnb = pd.read_csv("clean_airbnb.csv")
airbnb.head()
# Out:
#      id                                         name  host_id    host_name  \
# 0  2539                    clean quiet apt home park     2787         john
# 1  2595                        skylit midtown castle     2845     jennifer
# 2  3647                       village harlemnew york     4632    elisabeth
# 3  3831                 cozy entire floor brownstone     4869  lisaroxanne
# 4  5022  entire apt spacious studioloft central park     7192        laura
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  ...  last_review  reviews_per_month calculated_host_listings_count  \
# 0    149  ...   2018-10-19               0.21                              6
# 1    225  ...   2019-05-21               0.38                              2
# 2    150  ...          NaN               0.00                              1
# 3     89  ...   2019-07-05               4.64                              1
# 4     80  ...   2018-11-19               0.10                              1
#
#    availability_365  characters_in_name  symbols_in_name  \
# 0               365                  34                1
# 1               355                  21                0
# 2               365                  35                5
# 3               194                  31                0
# 4                 0                  48                2
#
#    exclamation_pts_in_name  numbers_in_name  caps_in_name  words_in_name
# 0                        0                0             1              7
# 1                        0                0             3              3
# 2                        1                0            25              6
# 3                        0                0             4              5
# 4                        0                0             5              7
#
# [5 rows x 22 columns]

# %%
airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.885800e+04  4.885800e+04  48858.000000  48858.000000  48858.000000
# mean   1.902335e+07  6.763169e+07     40.728941    -73.952170    152.740309
# std    1.098289e+07  7.862389e+07      0.054528      0.046159    240.232386
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.475980e+06  7.818669e+06     40.690090    -73.983070     69.000000
# 50%    1.969114e+07  3.079133e+07     40.723070    -73.955680    106.000000
# 75%    2.915765e+07  1.074344e+08     40.763107    -73.936280    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48858.000000       48858.000000       48858.000000
# mean         7.012444          23.273098           1.091124
# std         20.019757          44.549898           1.597270
# min          1.000000           0.000000           0.000000
# 25%          1.000000           1.000000           0.040000
# 50%          3.000000           5.000000           0.370000
# 75%          5.000000          24.000000           1.580000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365  characters_in_name  \
# count                    48858.000000      48858.000000        48858.000000
# mean                         7.148369        112.801425           36.907119
# std                         32.964600        131.610962           10.494872
# min                          1.000000          0.000000            1.000000
# 25%                          1.000000          0.000000           31.000000
# 50%                          1.000000         45.000000           37.000000
# 75%                          2.000000        227.000000           46.000000
# max                        327.000000        365.000000          179.000000
#
#        symbols_in_name  exclamation_pts_in_name  numbers_in_name  \
# count     48858.000000             48858.000000     48858.000000
# mean          1.017336                 0.160608         0.518196
# std           1.576561                 0.485724         0.959848
# min           0.000000                 0.000000         0.000000
# 25%           0.000000                 0.000000         0.000000
# 50%           1.000000                 0.000000         0.000000
# 75%           2.000000                 0.000000         1.000000
# max          47.000000                 9.000000        14.000000
#
#        caps_in_name  words_in_name
# count  48858.000000   48858.000000
# mean       5.534856       5.766220
# std        5.952159       1.814807
# min        0.000000       1.000000
# 25%        3.000000       5.000000
# 50%        4.000000       6.000000
# 75%        6.000000       7.000000
# max       45.000000      27.000000

# %% [markdown]
# We will remove data that seems unusual, like for example, a price of 0

# %%
airbnb.drop(airbnb[airbnb["price"] == 0].index, inplace = True)
#remove NA's.
airbnb.isna().sum()
# Out:
# id                                    0
# name                                122
# host_id                               0
# host_name                            98
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10036
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# characters_in_name                    0
# symbols_in_name                       0
# exclamation_pts_in_name               0
# numbers_in_name                       0
# caps_in_name                          0
# words_in_name                         0
# dtype: int64

# %%
#remove any NA
airbnb.dropna(inplace=True)

# %% [markdown]
# It seems like most of the "minimum nights" occur between 1 and 40. We will subset this.

# %%
airbnb.drop(airbnb[airbnb["price"] >200 ].index, inplace = True)

# %%
airbnb.drop(airbnb[airbnb["minimum_nights"] > 10 ].index, inplace = True)

# %%
#remove availability_365
#remove name
#remove host_
airbnb.drop(["name", "host_name", "neighbourhood", "availability_365", "last_review"], axis = 1, inplace=True)

# %%
airbnb.shape
# Out:
# (29304, 17)

# %%
airbnb.head()
# Out:
#      id  host_id neighbourhood_group  latitude  longitude        room_type  \
# 0  2539     2787            Brooklyn  40.64749  -73.97237     Private room
# 3  3831     4869            Brooklyn  40.68514  -73.95976  Entire home/apt
# 4  5022     7192           Manhattan  40.79851  -73.94399  Entire home/apt
# 5  5099     7322           Manhattan  40.74767  -73.97500  Entire home/apt
# 7  5178     8967           Manhattan  40.76489  -73.98493     Private room
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 3     89               1                270               4.64
# 4     80              10                  9               0.10
# 5    200               3                 74               0.59
# 7     79               2                430               3.47
#
#    calculated_host_listings_count  characters_in_name  symbols_in_name  \
# 0                               6                  34                1
# 3                               1                  31                0
# 4                               1                  48                2
# 5                               1                  41                0
# 7                               1                  31                0
#
#    exclamation_pts_in_name  numbers_in_name  caps_in_name  words_in_name
# 0                        0                0             1              7
# 3                        0                0             4              5
# 4                        0                0             5              7
# 5                        0                1             8              7
# 7                        0                0             5              5

# %% [markdown]
# Create dummy variables

# %%
le = LabelEncoder()
n = airbnb["neighbourhood_group"]
r = airbnb["room_type"]
airbnb["neighbourhood_group"] = le.fit_transform(n)
airbnb["room_type"] = le.fit_transform(r)

# %%
airbnb.head()
# Out:
#      id  host_id  neighbourhood_group  latitude  longitude  room_type  price  \
# 0  2539     2787                    1  40.64749  -73.97237          1    149
# 3  3831     4869                    1  40.68514  -73.95976          0     89
# 4  5022     7192                    2  40.79851  -73.94399          0     80
# 5  5099     7322                    2  40.74767  -73.97500          0    200
# 7  5178     8967                    2  40.76489  -73.98493          1     79
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9               0.21
# 3               1                270               4.64
# 4              10                  9               0.10
# 5               3                 74               0.59
# 7               2                430               3.47
#
#    calculated_host_listings_count  characters_in_name  symbols_in_name  \
# 0                               6                  34                1
# 3                               1                  31                0
# 4                               1                  48                2
# 5                               1                  41                0
# 7                               1                  31                0
#
#    exclamation_pts_in_name  numbers_in_name  caps_in_name  words_in_name
# 0                        0                0             1              7
# 3                        0                0             4              5
# 4                        0                0             5              7
# 5                        0                1             8              7
# 7                        0                0             5              5

# %%
x = airbnb.drop(["price"], axis = 1)
y = airbnb[["price"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)
reg = LinearRegression().fit(X_train, y_train)
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
1 - reg.score(X_test, y_test)
# Out:
# 0.5384644655585028

# %%
parameters = {'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
grid.fit(X_train, y_train) 
grid_predictions = grid.predict(X_test)
print(grid.best_params_) 
print(classification_report(y_test, grid_predictions))
